# %%
print ("Look what i can do")
# Out:
# Look what i can do

# %% [markdown]
# My name is Andrew Hooper
# I'm excited to learn python and SQL
# I took programing classes in college (2006)
# I learned html, javascript, and C++
# Today I am a liscenced Scrum Master who is looking to expand my data visualzation techniques
